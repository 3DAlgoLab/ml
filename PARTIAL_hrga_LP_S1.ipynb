# %% [markdown]
# # Milestone 1: Setting up an Image Pipeline

# %% [markdown]
# Data is the crucial part of any machine learning project, no less (and sometimes more!) important than your choice of algorithm. Naturally, preparing a data pipeline that can handle pre-processing as well as augmentation of your dataset is typically the first piece of code that you write for an ML project.
#
# PyTorch provides several tools that facilitate data loading and pre-processing. There are generally two classes that are involved in this task: a `torch.utils.data.Dataset` and a `torch.utils.data.DataLoader`. The Dataset class is the one that you will often need to write your own custom code for, that is going to inherit the abstract PyTorch class. There are at least two methods that you are going to have to override: `__len__` and `__getitem__`. These will allow you to get the size of your dataset via `len(dataset)` and access each datasample as `dataset[index]`. Additionally, for large datasets and/or high dimensional data, such as images, it is convenient to employ **lazy data loading**, where we are going to load each sample as needed, rather than keeping the entire dataset in the memory at once.
#
# The training sample returned by `dataset[index]` is going to depend on whether the data is labeled or not. In the former case, the return value will
# be an image-label pair, whereas in the unlabeled case it is simply an image. Since we will be using both kinds of data for our project, we will write two
# separate Dataset classes, starting with the unlabeled one.

# %% [markdown]
# ## Part A: the Unlabeled Dataset

# %%
import os
from os import listdir
from os.path import join

from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

import torch 
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms

# Define a function to check if a file is actually an image.
from pathlib import Path

def is_image(filename):
    if isinstance(filename, str):
        filename = Path(filename)
    return filename.suffix in ['.jpg', '.jpeg', '.png', '.ppm', '.bmp', '.pgm', '.tif']

class UnlabeledDataset(Dataset):

    def __init__(self, dir_path, transform=None):
        """
        Args:
            dir_path (string): Directory containing the images.
            transform (optional): Optional transform to be applied
                on an image.
        """

        # The list of all the image file names (but not the images themselves!) will be read
        # when the Dataset object is initialized
        p = Path(dir_path).resolve()
        self.img_path_list = [f for f in p.iterdir() if is_image(f)]
        self.transform = transform

    def __len__(self):
        return len(self.img_path_list)

    def __getitem__(self, idx):

        # Here is where the image actually gets read:
        img_path = self.img_path_list[idx]
        # img = read_image(str(img_path)).type(torch.float32)/255.0        
        img = Image.open(img_path)
        if self.transform:
            img = self.transform(img)           
        return img

# %%
# Instantiate the class, print the number of images in the set, and show an image
unlabeled_set = UnlabeledDataset('data/MelanomaDetection/unlabeled')
print('Number of image is {}'.format(len(unlabeled_set)))
unlabeled_set[7017]
# Out:
# Number of image is 7018
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x32>

# %% [markdown]
# ## Part B: the Labeled Dataset
#
# The labeled Dataset class is very similar, except that now we also care about whether the image is labeled as melanoma-positive or melanomanegative.
# In the provided dataset folder, images containing melanoma have filenames that end with `*_1.jpg`, whereas benign images are named `*_0.jpg`.
# That is what we are going to use to get the labels that we return (along with the respective images) in the `__getitem__` method:

# %%
class LabeledDataset(Dataset):

    def __init__(self, dir_path, transform=None):
        """
        Args:
            dir_path (string): Directory containing the images.
            transform (optional): Optional transform to be applied
                on an image.
        """

        # The list of all the image file names (but not the images themselves!) will be read
        # when the Dataset object is initialized
        p = Path(dir_path).resolve()
        self.img_path_list = [f for f in p.iterdir() if is_image(f)]
        self.transform = transform

    def __len__(self):
        return len(self.img_path_list)    

    def __getitem__(self, idx):      
 
        # Here is where the image actually gets read:
        img_path = self.img_path_list[idx]
        # img = read_image(str(img_path)).type(torch.float32)/255.0        
        img = Image.open(img_path)
        if self.transform:
            img = self.transform(img)            
        
        label = int(img_path.stem.split('_')[1])
        return img, label

# %%
# Instantiate the class, print the number of images in the set, and show an image with the corresponding label
labeled_set = LabeledDataset("data/MelanomaDetection/labeled/")

print('Number of image is {}'.format(len(labeled_set)))
print('Label:', labeled_set[0][1])

labeled_set[0][0]
# Out:
# Number of image is 200
# Label: 0
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x32>

# %% [markdown]
# ### So what is this `transform` about?
#
# What we have seen above is datasets returning images in the form of objects of type `PIL.PngImagePlugin.PngImageFile`. However, what we need to train a PyTorch model are PyTorch **tensors**. This requirement can be easily communicated to the dataset when we instantiate it via the `transform` argument:

# %%
unlabeled_set = UnlabeledDataset('data/MelanomaDetection/unlabeled', 
                                 transform=transforms.ToTensor())
labeled_set = LabeledDataset('data/MelanomaDetection/labeled', 
                             transform=transforms.ToTensor())

unlabeled_set[0].min(), unlabeled_set[0].max()
# Out:
# (tensor(0.2824), tensor(0.9725))

# %% [markdown]
# Now that we have the dataset, are we ready to use our data for training a model? Not quite yet. PyTorch has another class called `torch.utils.data.DataLoader` that takes care of splitting the data into minibatches of a given size, shuffling it if needed, and loading it in parallel by using multiprocessing workers.
#
# ## Part C: the DataLoader(s)

# %%
# Create a torch.utils.data.DataLoader object for unlabeled images
unlabeled_loader = DataLoader(unlabeled_set, batch_size=4, shuffle=True)

# Print out batches of data
for batch_idx, batch in enumerate(unlabeled_loader):
  
    # Stop after two batches
    if batch_idx >= 2:
        break 

    # torchvision provides functions that facilitate displaying batches
    # of images that come in the form of PyTorch tensors:
    print(f"Shape of batch {batch_idx} : {batch.shape}")
    image_grid = torchvision.utils.make_grid(batch, nrow=4)
    plt.imshow(image_grid.permute(1, 2, 0))
    plt.pause(0.05)
# Out:
# Shape of batch 0 : torch.Size([4, 3, 32, 32])
# Shape of batch 1 : torch.Size([4, 3, 32, 32])

# %% [markdown]
# (As you can see, the batches that are produced inside the loop are PyTorch tensors with the following shape: batch_size x number_of_channels x
# dimenstion_x x dimension_y)

# %%
# Create a torch.utils.data.DataLoader object for labeled images
labeled_loader = DataLoader(labeled_set, batch_size=4, shuffle=True)


# Print out batches of data    
for batch_idx, batch in enumerate(labeled_loader):    
    if batch_idx >= 2:
        break 
    
    print("Batch labels", batch[1].data)
    image_grid = torchvision.utils.make_grid(batch[0], nrow=4)
    plt.imshow(image_grid.permute(1, 2, 0))
    plt.pause(0.05)
# Out:
# Batch labels tensor([1, 0, 0, 0])
# Batch labels tensor([0, 0, 1, 1])

# %% [markdown]
# ## Part D: Data Augmentation
# While training our model, we are going to make use of the data augmentation techniques. In other words, we are going to randomly apply
# transformations to the images in our dataset, that result in (somewhat) different images that nevertheless correspond to the same class (melanoma
# positive or negative) as the original sample.
#
# The `torchvision.transforms` package contains a rich variety of transformations such as resizing,
# cropping, flipping, normalizing, rotations, changing colors, etc, that can be applied at random with a probability of your choice.
#
# Here the images in the
# dataset come in 32x32 pixels, and let us say that we would like to keep them that size for our model. (They are small enough that shrinking them would
# almost certainly be a bad idea, and enlarging them would only encrease the dimensionality of our inputs while keeping the amount of useful information
# unchanged). This leaves us with quite a few options, including e.g. horizontal and vertical flips, as well as rotations (keep in mind that occasionally
# rotations may result in removing the relevant part of the sample from the augmented image).
#
# We are only going to apply augmentation transforms to our training data (both labeled and unlabeled), but not to the test set, to minimize any
# unintended effects. (In fact, if you are truly unsure of whether certain augmentations make sense for your data, it may be worthwhile to compare the
# final performance of two models, one trained with data augmentation and one without.)

# %%
# Rotations
# Here I chose a limited range of rotations to minimize parts of 
# the images that get omitted in the process

rotation = transforms.RandomChoice([transforms.RandomRotation([-3, 3]), 
                                    transforms.RandomRotation([87, 93]), 
                                    transforms.RandomRotation([177,183]),
                                    transforms.RandomRotation([267, 273])])
# Use transforms.Compose to combine different transformations of 
# your choice

augmentation = transforms.Compose([transforms.RandomHorizontalFlip(), 
                                   transforms.RandomVerticalFlip(), 
                                   rotation])

# %% [markdown]
# Hence, the final version of the code that I will use for initializing the training and testing datasets is going to look like this:

# %%
# Provide the transformations as an argument when instantiating the Dataset classes
# Unlabeled set 
unlabeled_set = LabeledDataset("data/MelanomaDetection/unlabeled/", transform=transforms.Compose([transforms.ToTensor(), augmentation]))

# Labeled set 
labeled_set = LabeledDataset("data/MelanomaDetection/labeled/", transform=transforms.Compose([transforms.ToTensor(), augmentation]))
# Test set                             
test_set = LabeledDataset("data/MelanomaDetection/test/", transform=transforms.Compose(transforms.ToTensor()))
